# %% [markdown]
# # Predicting Vehicle MPG

# %% [markdown]
# # Importing Data

# %%
import os
import pandas as pd
import numpy as np

os.getcwd()

headers = ['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin','car name']

auto_data = pd.read_csv('Data-CSVs/auto-mpg.data', delimiter='\s+', names=headers)

auto_data.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
# 5  15.0          8         429.0      198.0  4341.0          10.0          70
# 6  14.0          8         454.0      220.0  4354.0           9.0          70
# 7  14.0          8         440.0      215.0  4312.0           8.5          70
# 8  14.0          8         455.0      225.0  4425.0          10.0          70
# 9  15.0          8         390.0      190.0  3850.0           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 5       1           ford galaxie 500
# 6       1           chevrolet impala
# 7       1          plymouth fury iii
# 8       1           pontiac catalina
# 9       1         amc ambassador dpl

# %% [markdown]
# # Visualizing Data

# %%
auto_data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
#here I am using the DataFrame.hist() method that comes with pandas
#it's kinda poopy

auto_data.hist(bins=25)

import matplotlib.pyplot as plt

plt.show()

# %%
#the book used a scatter matrix to map all the data against itself
#It is a good way to narrow down your options and see what attributes positively correlate

from pandas.plotting import scatter_matrix

attributes = ['mpg','displacement','weight','acceleration']

scatter_matrix(auto_data[attributes], figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000229D2CE1588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3D44DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3AB6B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3AC9D88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3B02408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3B36A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3B6C608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3BA3B88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3BAE788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3BE9948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3C4DF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3EE7F48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3F24088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3F5D1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3F942C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229D3FCD3C8>]],
#       dtype=object)

# %%
#This creates a correlation matrix to see what data is correlated with what attributes
#we can see that model year has a slightly positive correlation and 
#weight has a largely negative correlation

#perhaps we should use weight and a linear regression? (phil's thoughts)

auto_corr = auto_data.corr()

auto_corr['mpg'].sort_values(ascending=False)
# Out:
# mpg             1.000000
# model year      0.579267
# origin          0.563450
# acceleration    0.420289
# cylinders      -0.775396
# displacement   -0.804203
# weight         -0.831741
# Name: mpg, dtype: float64
